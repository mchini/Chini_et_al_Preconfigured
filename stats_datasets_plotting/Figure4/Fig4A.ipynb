# %% [markdown]
# # import packages and data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# set seaborn theme
sns.set_theme()

# load data
data = pd.read_excel('E:/PFCmicro/skeweness_paper/Chini_et_al_Preconfigured/stats_datasets_plotting/Figure4/df_firing.xlsx')
# only keep PFC for the sample figures
data = data.loc[data['b_area'] != 1]
# convert everything to log coordinates
data['medSTTC'] = np.log10(data['medSTTC'] - np.nanmin(data['medSTTC']) + 0.0001)
data['f_rate'] = np.log10(data['f_rate'])

# %%
plt.figure()
plt.scatter(data.f_rate[data.age == 6],
            data.medSTTC[data.age == 6])
plt.ylim(-2, -0.75)
plt.xlim(-3, 1)
# Out:
# (-3.0, 1.0)

# %%
plt.figure()
plt.scatter(data.f_rate[data.age == 8],
            data.medSTTC[data.age == 8])
plt.ylim(-2, -0.75)
plt.xlim(-3, 1)
# Out:
# (-3.0, 1.0)

# %%
plt.figure()
plt.scatter(data.f_rate[data.age == 10],
            data.medSTTC[data.age == 10])
plt.ylim(-2, -0.75)
plt.xlim(-3, 1)
# Out:
# (-3.0, 1.0)
