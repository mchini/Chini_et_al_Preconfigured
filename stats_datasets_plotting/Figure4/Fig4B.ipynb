# %% [markdown]
# # import packages and data

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# set seaborn theme
sns.set_theme()

# load data 
data = pd.read_excel('load hub_f_rate.xlsx here')
data.f_rate = np.log10(data.f_rate)

# %%
plt.figure()
sns.violinplot(x='hub_score', y='f_rate', cut=0,
              data=data, palette='PRGn', scale='width')
# Out:
# <Axes: xlabel='hub_score', ylabel='f_rate'>
