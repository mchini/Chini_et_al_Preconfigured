# %% [markdown]
# # import packages

# %%
import numpy as np
from scipy.io import loadmat
from scipy.stats import zscore
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # load modeling and exp data

# %%
# set seaborn theme
sns.set_theme()

# load modeling data
data = pd.read_excel('E:/PFCmicro/skeweness_paper/Chini_et_al_Preconfigured/stats_datasets_plotting/Figure5/df_NN_syms.xlsx')

# set order for plot
order = [0, 1, 2, 3]

# %% [markdown]
# # plot the distance from the experimental data

# %%
plt.figure()
sns.violinplot(x='extreme_params', y='dist7', cut=0,
              data=data, color='w',
              scale='width', order=order)
# Out:
# <Axes: xlabel='extreme_params', ylabel='dist7'>
